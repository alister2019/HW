# %% [markdown]
# ## домашнее задание:
# (можно выполнять прям в ячейках, или скопировав код в
# PyCharm)

# %%
# задание 1
# какие из этих строк можно конкатенировать? Какие умножать? Какие вычитать? Запишите все результаты, которые у Вас получились
a = 23
b = 34.02
c = "python is cool"
d = "you are cool, too"

# %%
print(a+b)
print(a*b)
print(b-a)
print(c*2)
print(c+d)
print(c*a)
# Out:
# 57.02
# 782.46
# 11.020000000000003
# python is coolpython is cool
# python is coolyou are cool, too
# python is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is coolpython is cool

# %%
# задание 2
"""
Придумайте такую строку (на любом знакомом Вам языке),чтобы она состояла из трех других (повторы строки разрешены).
Напишите код. Если вы можете сделать это более, чем одним способом, напишите все способы
"""

# %%
lud1 = 'Сяпала Калуша с Калушатами по напушке.'
lud2 = ' И увазила Бутявку и волит: '
lud3 = '- Калушата! Калушаточки! Бутявка!'
lud = lud1 + lud2 + lud3
print(lud)

lud4 = (lud*3)
print(lud4)

p = 3
lud5 = lud*3
print(lud5)

print('Калушата! '*3)
print('Калушата! '*p)
# Out:
# Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!
# Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!
# Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!Сяпала Калуша с Калушатами по напушке. И увазила Бутявку и волит: - Калушата! Калушаточки! Бутявка!
# Калушата! Калушата! Калушата!
# Калушата! Калушата! Калушата!

# %%
# задание 3
"""
Как из слова "апельсин" сделать слово "спаниель" ? 
Подсказка: вам помогут срезы и операции с индексами
"""
# Out:
# '\nКак из слова "апельсин" сделать слово "спаниель" ? \nПодсказка: вам помогут срезы и операции с индексами\n'

# %%
x = "апельсин"
print(x)
s = x[-3]+x[1::-1]+x[-1]+x[6]+x[2:5]
print(s)
# Out:
# апельсин
# спаниель

# %%
# задание 4 (выполняется по желанию)
"""элементы в переменной text преобразуйте в нижний регистр, а затем запишите наоборот, с последнего элемента по первый"""
text = "WOW,NOEL SEES LEON"
print(text[::-1])
print(text.lower())
print(text.lower()[::-1])
# Out:
# NOEL SEES LEON,WOW
# wow,noel sees leon
# noel sees leon,wow
